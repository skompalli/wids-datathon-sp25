# %%
import sys
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
print("path: "+ sys.executable)
# Out:
# path: /Users/suparna/Desktop/datathon/wids-datathon-sp25/venv/bin/python

# %%
quantitative = pd.read_excel("../TRAIN/TRAIN_QUANTITATIVE_METADATA.xlsx")
quantitative.head()

# %%
solutions = pd.read_excel("../TRAIN/TRAINING_SOLUTIONS.xlsx")
solutions.head()
# Out:
#   participant_id  ADHD_Outcome  Sex_F
# 0   UmrK0vMLopoR             1      1
# 1   CPaeQkhcjg7d             1      0
# 2   Nb4EetVPm3gs             1      0
# 3   p4vPhVu91o4b             1      1
# 4   M09PXs7arQ5E             1      1

# %%
def remove_outliers_zscore(data, threshold=3):
    z = np.abs(stats.zscore(data))
    return data[z < threshold]

def remove_outliers_iqr(data):
    q1 = np.percentile(data, 25)
    q3 = np.percentile(data, 75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    return data[(data >= lower_bound) & (data <= upper_bound)]

# %%
cp = df[["participant_id", "APQ_P_APQ_P_CP"]]
cp_sol = pd.merge(cp, solutions, on='participant_id', how='left').drop(columns="participant_id")
cp_sol = remove_outliers_zscore(cp_sol)
cp_sol.head()
g = sns.FacetGrid(cp_sol, col='Sex_F', row='ADHD_Outcome', margin_titles=True, height=2)
g.map(sns.boxplot, 'APQ_P_APQ_P_CP')
# Out:
# /Users/suparna/Desktop/datathon/wids-datathon-sp25/venv/lib/python3.11/site-packages/seaborn/axisgrid.py:718: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
cp = df[["participant_id", "APQ_P_APQ_P_ID"]]
cp_sol = pd.merge(cp, solutions, on='participant_id', how='left').drop(columns="participant_id")
cp_sol = remove_outliers_iqr(cp_sol)
g = sns.FacetGrid(cp_sol, col='Sex_F', row='ADHD_Outcome', margin_titles=True, height=2)
g.map(sns.boxplot, 'APQ_P_APQ_P_ID')
# Out:
# /Users/suparna/Desktop/datathon/wids-datathon-sp25/venv/lib/python3.11/site-packages/seaborn/axisgrid.py:718: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
cp = df[["participant_id", "APQ_P_APQ_P_INV"]]
cp_sol = pd.merge(cp, solutions, on='participant_id', how='left').drop(columns="participant_id")
cp_sol = remove_outliers_zscore(cp_sol)
g = sns.FacetGrid(cp_sol, col='Sex_F', row='ADHD_Outcome', margin_titles=True, height=2)
g.map(sns.boxplot, 'APQ_P_APQ_P_INV')
# Out:
# /Users/suparna/Desktop/datathon/wids-datathon-sp25/venv/lib/python3.11/site-packages/seaborn/axisgrid.py:718: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
cp = df[["participant_id", "APQ_P_APQ_P_OPD"]]
cp_sol = pd.merge(cp, solutions, on='participant_id', how='left').drop(columns="participant_id")
cp_sol = remove_outliers_zscore(cp_sol)
g = sns.FacetGrid(cp_sol, col='Sex_F', row='ADHD_Outcome', margin_titles=True, height=2)
g.map(sns.boxplot, 'APQ_P_APQ_P_OPD')
# Out:
# /Users/suparna/Desktop/datathon/wids-datathon-sp25/venv/lib/python3.11/site-packages/seaborn/axisgrid.py:718: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
